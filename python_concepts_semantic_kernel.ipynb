# %% [markdown]
# <a href="https://colab.research.google.com/github/farahelmashad/ai-agents-microsoft-course/blob/main/python_concepts_semantic_kernel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install semantic-kernel
# Out:
# Collecting semantic-kernel
#   Downloading semantic_kernel-1.36.2-py3-none-any.whl.metadata (12 kB)
# Collecting azure-ai-projects>=1.0.0b12 (from semantic-kernel)
#   Downloading azure_ai_projects-1.1.0b4-py3-none-any.whl.metadata (24 kB)
# Collecting azure-ai-agents>=1.2.0b3 (from semantic-kernel)
#   Downloading azure_ai_agents-1.2.0b4-py3-none-any.whl.metadata (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp~=3.8 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (3.12.15)
# Collecting cloudevents~=1.0 (from semantic-kernel)
#   Downloading cloudevents-1.12.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (2.11.7)
# Requirement already satisfied: pydantic-settings~=2.0 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (2.10.1)
# Requirement already satisfied: defusedxml~=0.7 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (0.7.1)
# Collecting azure-identity>=1.13 (from semantic-kernel)
#   Downloading azure_identity-1.25.0-py3-none-any.whl.metadata (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (2.0.2)
# Requirement already satisfied: openai>=1.98.0 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (1.106.1)
# Collecting openapi_core<0.20,>=0.18 (from semantic-kernel)
#   Downloading openapi_core-0.19.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: websockets<16,>=13 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (15.0.1)
# Collecting aiortc>=1.9.0 (from semantic-kernel)
#   Downloading aiortc-1.13.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: opentelemetry-api~=1.24 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (1.36.0)
# Collecting prance<25.4.9,>=23.6.21 (from semantic-kernel)
#   Downloading prance-25.4.8.0-py3-none-any.whl.metadata (13 kB)
# Collecting pybars4~=0.9 (from semantic-kernel)
#   Downloading pybars4-0.9.13.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jinja2~=3.1 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (3.1.6)
# Requirement already satisfied: nest-asyncio~=1.6 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (1.6.0)
# Requirement already satisfied: scipy>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (1.16.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (5.29.5)
# Requirement already satisfied: typing-extensions>=4.13 in /usr/local/lib/python3.12/dist-packages (from semantic-kernel) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.8->semantic-kernel) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.8->semantic-kernel) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.8->semantic-kernel) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.8->semantic-kernel) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.8->semantic-kernel) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.8->semantic-kernel) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.8->semantic-kernel) (1.20.1)
# Collecting aioice<1.0.0,>=0.10.1 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading aioice-0.10.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting av<15.0.0,>=14.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading av-14.4.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from aiortc>=1.9.0->semantic-kernel) (1.17.1)
# Collecting cryptography>=44.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading cryptography-45.0.7-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: google-crc32c>=1.1 in /usr/local/lib/python3.12/dist-packages (from aiortc>=1.9.0->semantic-kernel) (1.7.1)
# Collecting pyee>=13.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting pylibsrtp>=0.10.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading pylibsrtp-0.12.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting pyopenssl>=25.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading pyopenssl-25.2.0-py3-none-any.whl.metadata (17 kB)
# Collecting isodate>=0.6.1 (from azure-ai-agents>=1.2.0b3->semantic-kernel)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting azure-core>=1.30.0 (from azure-ai-agents>=1.2.0b3->semantic-kernel)
#   Downloading azure_core-1.35.1-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 3.6 MB/s eta 0:00:00
# Collecting azure-storage-blob>=12.15.0 (from azure-ai-projects>=1.0.0b12->semantic-kernel)
#   Downloading azure_storage_blob-12.26.0-py3-none-any.whl.metadata (26 kB)
# Collecting msal>=1.30.0 (from azure-identity>=1.13->semantic-kernel)
#   Downloading msal-1.33.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity>=1.13->semantic-kernel)
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting deprecation<3.0,>=2.0 (from cloudevents~=1.0->semantic-kernel)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2~=3.1->semantic-kernel) (3.0.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.98.0->semantic-kernel) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.98.0->semantic-kernel) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.98.0->semantic-kernel) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.98.0->semantic-kernel) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.98.0->semantic-kernel) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=1.98.0->semantic-kernel) (4.67.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (4.25.1)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading jsonschema_path-0.3.4-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (10.8.0)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading openapi_schema_validator-0.6.3-py3-none-any.whl.metadata (5.4 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading openapi_spec_validator-0.7.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting parse (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading parse-1.20.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting werkzeug<3.1.2 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading werkzeug-3.1.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api~=1.24->semantic-kernel) (8.7.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk~=1.24->semantic-kernel) (0.57b0)
# Requirement already satisfied: chardet>=5.2 in /usr/local/lib/python3.12/dist-packages (from prance<25.4.9,>=23.6.21->semantic-kernel) (5.2.0)
# Collecting ruamel.yaml>=0.18.10 (from prance<25.4.9,>=23.6.21->semantic-kernel)
#   Downloading ruamel.yaml-0.18.15-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from prance<25.4.9,>=23.6.21->semantic-kernel) (2.32.4)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from prance<25.4.9,>=23.6.21->semantic-kernel) (25.0)
# Collecting PyMeta3>=0.5.1 (from pybars4~=0.9->semantic-kernel)
#   Downloading PyMeta3-0.5.1.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings~=2.0->semantic-kernel) (1.1.1)
# Collecting dnspython>=2.0.0 (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting ifaddr>=0.2.0 (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel)
#   Downloading ifaddr-0.2.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai>=1.98.0->semantic-kernel) (3.10)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from azure-core>=1.30.0->azure-ai-agents>=1.2.0b3->semantic-kernel) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.0->aiortc>=1.9.0->semantic-kernel) (2.22)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.98.0->semantic-kernel) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.98.0->semantic-kernel) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.98.0->semantic-kernel) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel) (3.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.27.1)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (6.0.2)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading pathable-0.4.4-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity>=1.13->semantic-kernel) (2.10.1)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.1.4)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading lazy_object_proxy-1.12.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->prance<25.4.9,>=23.6.21->semantic-kernel) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->prance<25.4.9,>=23.6.21->semantic-kernel) (2.5.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.18.10->prance<25.4.9,>=23.6.21->semantic-kernel)
#   Downloading ruamel.yaml.clib-0.2.12-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Downloading semantic_kernel-1.36.2-py3-none-any.whl (888 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 888.6/888.6 kB 43.4 MB/s eta 0:00:00
# Downloading aiortc-1.13.0-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 7.9 MB/s eta 0:00:00
# Downloading azure_ai_agents-1.2.0b4-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.7/214.7 kB 15.3 MB/s eta 0:00:00
# Downloading azure_ai_projects-1.1.0b4-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 kB 9.6 MB/s eta 0:00:00
# Downloading azure_identity-1.25.0-py3-none-any.whl (190 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 13.9 MB/s eta 0:00:00
# Downloading cloudevents-1.12.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 3.9 MB/s eta 0:00:00
# Downloading openapi_core-0.19.5-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 8.2 MB/s eta 0:00:00
# Downloading prance-25.4.8.0-py3-none-any.whl (36 kB)
# Downloading aioice-0.10.1-py3-none-any.whl (24 kB)
# Downloading av-14.4.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.5/35.5 MB 52.6 MB/s eta 0:00:00
# Downloading azure_core-1.35.1-py3-none-any.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 kB 15.6 MB/s eta 0:00:00
# Downloading azure_storage_blob-12.26.0-py3-none-any.whl (412 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.9/412.9 kB 30.7 MB/s eta 0:00:00
# Downloading cryptography-45.0.7-cp311-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 102.9 MB/s eta 0:00:00
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading jsonschema_path-0.3.4-py3-none-any.whl (14 kB)
# Downloading msal-1.33.0-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 9.3 MB/s eta 0:00:00
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Downloading openapi_schema_validator-0.6.3-py3-none-any.whl (8.8 kB)
# Downloading openapi_spec_validator-0.7.2-py3-none-any.whl (39 kB)
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Downloading pylibsrtp-0.12.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 81.1 MB/s eta 0:00:00
# Downloading pyopenssl-25.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 4.6 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.15-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 8.9 MB/s eta 0:00:00
# Downloading werkzeug-3.1.1-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.4/224.4 kB 14.5 MB/s eta 0:00:00
# Downloading parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 24.4 MB/s eta 0:00:00
# Downloading ifaddr-0.2.0-py3-none-any.whl (12 kB)
# Downloading lazy_object_proxy-1.12.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.3 MB/s eta 0:00:00
# Downloading pathable-0.4.4-py3-none-any.whl (9.6 kB)
# Downloading ruamel.yaml.clib-0.2.12-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (754 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 754.1/754.1 kB 40.0 MB/s eta 0:00:00
# Building wheels for collected packages: pybars4, PyMeta3
#   Building wheel for pybars4 (setup.py) ... done
#   Created wheel for pybars4: filename=pybars4-0.9.13-py3-none-any.whl size=14340 sha256=93db4e94fef0925983c93bfcb51c99b9f32563968f440ee292e74396727352ff
#   Stored in directory: /root/.cache/pip/wheels/75/2d/da/c75b2fc7b00dc9c154dff65f689a318e7d24b44c612c2b21f1
#   Building wheel for PyMeta3 (setup.py) ... done
#   Created wheel for PyMeta3: filename=PyMeta3-0.5.1-py3-none-any.whl size=16449 sha256=0bb8b4a5e2ddc5b47d82cb551dae772dedb07d47bb14b74d9f7482bcd1adc010
#   Stored in directory: /root/.cache/pip/wheels/5a/9b/2c/81b7551d2c05a482817e6c3b3d2f8ad2a0229db874c4bc6346
# Successfully built pybars4 PyMeta3
# Installing collected packages: PyMeta3, parse, ifaddr, werkzeug, ruamel.yaml.clib, pyee, pybars4, pathable, lazy-object-proxy, isodate, dnspython, deprecation, av, ruamel.yaml, pylibsrtp, jsonschema-path, cryptography, cloudevents, azure-core, aioice, pyopenssl, prance, azure-storage-blob, azure-ai-agents, openapi-schema-validator, msal, azure-ai-projects, aiortc, openapi-spec-validator, msal-extensions, openapi_core, azure-identity, semantic-kernel
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.1.3
#     Uninstalling Werkzeug-3.1.3:
#       Successfully uninstalled Werkzeug-3.1.3
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 43.0.3
#     Uninstalling cryptography-43.0.3:
#       Successfully uninstalled cryptography-43.0.3
#   Attempting uninstall: pyopenssl
#     Found existing installation: pyOpenSSL 24.2.1
#     Uninstalling pyOpenSSL-24.2.1:
#       Successfully uninstalled pyOpenSSL-24.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 45.0.7 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.2.0 which is incompatible.
# Successfully installed PyMeta3-0.5.1 aioice-0.10.1 aiortc-1.13.0 av-14.4.0 azure-ai-agents-1.2.0b4 azure-ai-projects-1.1.0b4 azure-core-1.35.1 azure-identity-1.25.0 azure-storage-blob-12.26.0 cloudevents-1.12.0 cryptography-45.0.7 deprecation-2.1.0 dnspython-2.8.0 ifaddr-0.2.0 isodate-0.7.2 jsonschema-path-0.3.4 lazy-object-proxy-1.12.0 msal-1.33.0 msal-extensions-1.3.1 openapi-schema-validator-0.6.3 openapi-spec-validator-0.7.2 openapi_core-0.19.5 parse-1.20.2 pathable-0.4.4 prance-25.4.8.0 pybars4-0.9.13 pyee-13.0.0 pylibsrtp-0.12.0 pyopenssl-25.2.0 ruamel.yaml-0.18.15 ruamel.yaml.clib-0.2.12 semantic-kernel-1.36.2 werkzeug-3.1.1

# %%
import os
from typing import Annotated
from openai import AsyncOpenAI

from dotenv import load_dotenv

from semantic_kernel.agents import ChatCompletionAgent, ChatHistoryAgentThread
from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion
from semantic_kernel.functions import kernel_function

# %%
os.environ["GITHUB_TOKEN"] = ""

# %%
import random

class StudyPythonPlugin:
  def __init__(self):
    self.topics = ['variables and data types in python','conditional statements (if-else) in python','loops in python (for, while)','functions in python','classes and objects in python','inheritance in python','polymorphism in python','encapsulation in python','abstraction in python','lists in python','tuples in python','sets in python','dictionaries in python','stacks in python','queues in python','linked lists in python',
               'trees in python','graphs in python','list comprehensions in python','lambda functions in python','decorators in python','generators in python','iterators in python','error and exception handling in python','file handling in python','modules and packages in python','regular expressions in python']
    self.explained_topics=[]
    self.last_explained_topic=None
    @kernel_function(description='Picks a random subject and explains it')
    def explain_subject(self) -> str:
      self.last_explained_topic=random.choice(self.topics)
      self.topics.remove(self.last_explained_topic)
      self.explained_topics.append(self.last_explained_topic)
      return self.last_explained_topic

# %%
client = AsyncOpenAI(
    api_key=os.environ.get("GITHUB_TOKEN"),
    base_url="https://models.inference.ai.azure.com/",
)

chat_completion_service = OpenAIChatCompletion(
    ai_model_id="gpt-4o-mini",
    async_client=client,
)

# %%
agent = ChatCompletionAgent(
    service=chat_completion_service,
    plugins=[StudyPythonPlugin()],
    name="StudyPythonAgent",
    instructions="You are a helpful AI Agent that can help explain python concepts to students giving them explanation and multiple code examples with varying difficulty levels",
)

# %%
async def main():
    thread: ChatHistoryAgentThread | None = None

    user_inputs = [
        "Explain to me a random python concept",
        'I didn\'t understand this concept quite well can you explain it again?'
    ]

    for user_input in user_inputs:
        print(f"# User: {user_input}\n")
        first_chunk = True
        async for response in agent.invoke_stream(
            messages=user_input, thread=thread,
        ):
            if first_chunk:
                print(f"# {response.name}: ", end="", flush=True)
                first_chunk = False
            print(f"{response}", end="", flush=True)
            thread = response.thread
        print()

    await thread.delete() if thread else None

await main()
# Out:
# # User: Explain to me a random python concept
#
# # StudyPythonAgent: Sure! Let's talk about **list comprehensions** in Python.
#
# ### What is a List Comprehension?
#
# A list comprehension is a concise way to create lists in Python. It's an elegant way to generate lists based on existing lists or other iterable objects. List comprehensions provide a shorter syntax when you want to create a new list by performing some operation on each item in an existing list.
#
# ### Basic Syntax
#
# The syntax of a list comprehension consists of brackets containing an expression followed by a `for` clause, and optionally, one or more `if` statements. The general structure is:
#
# ```python
# new_list = [expression for item in iterable if condition]
# ```
#
# - `expression` is the current item in the iteration, potentially modified.
# - `item` is the variable that takes the value of the current element in the iterable.
# - `iterable` is any Python iterable (like a list, tuple, etc.)
# - `condition` is optional; it filters items from the iterable.
#
# ### Example 1: Basic List Comprehension
#
# Let's start with a simple example that squares numbers from 0 to 9.
#
# ```python
# # Generate a list of squares from 0 to 9
# squares = [x**2 for x in range(10)]
# print(squares)  # Output: [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# ```
#
# ### Example 2: Using Conditionals
#
# List comprehensions can also include conditions. For instance, let’s create a list of even numbers from 0 to 19.
#
# ```python
# # Generate a list of even squares from 0 to 19
# even_squares = [x**2 for x in range(20) if x % 2 == 0]
# print(even_squares)  # Output: [0, 4, 16, 36, 64, 100, 144, 196]
# ```
#
# ### Example 3: Nested List Comprehensions
#
# You can also have nested list comprehensions. For example, if you want to create a 3x3 matrix, you could do it like this:
#
# ```python
# # Create a 3x3 matrix using nested list comprehension
# matrix = [[j for j in range(3)] for i in range(3)]
# print(matrix)  # Output: [[0, 1, 2], [0, 1, 2], [0, 1, 2]]
# ```
#
# ### Example 4: From Another List
#
# You can use list comprehensions to transform elements from one list into another. Here's an example that converts a list of names into uppercase.
#
# ```python
# # List of names
# names = ["alice", "bob", "charlie"]
#
# # Convert names to uppercase
# uppercase_names = [name.upper() for name in names]
# print(uppercase_names)  # Output: ['ALICE', 'BOB', 'CHARLIE']
# ```
#
# ### Conclusion
#
# List comprehensions are a powerful feature in Python that help you write cleaner and more readable code. They can replace many use cases for traditional for-loops when creating lists. However, while they are often shorter and clearer, be cautious not to make your list comprehensions too complex, as they can become difficult to read.
#
# Feel free to ask if you have any questions or want to explore another Python concept!
# # User: I didn't understand this concept quite well can you explain it again?
#
# # StudyPythonAgent: Of course! Let’s break down list comprehensions step by step and provide some additional explanations and examples.
#
# ### What is a List Comprehension?
#
# A list comprehension is a compact and convenient way to create lists in Python. Instead of using multiple lines of code with loops and appending to a list, you can create a new list in a single line.
#
# ### Basic Components
#
# 1. **Expression**: This is what you want to do to each item. For example, it could be squaring a number or converting a string to uppercase.
#
# 2. **For Clause**: This iterates over an iterable (like a list or range).
#
# 3. **If Clause (optional)**: This is for filtering items. It allows you to include only certain items in your new list based on a condition.
#
# ### Basic Syntax
#
# The syntax of a list comprehension looks like this:
#
# ```python
# new_list = [expression for item in iterable if condition]
# ```
#
# - **new_list**: This is the list you are creating.
# - **expression**: This could be any operation or transformation you want to apply to each item.
# - **item**: This represents the current value from the iterable during the iteration.
# - **iterable**: This is what you’re iterating over (like a list, tuple, or range).
# - **condition**: This is optional. It filters items so that only those items meeting the condition are included.
#
# ### Example Breakdown
#
# #### Example 1: Squaring Numbers
# Let’s start simple. Say we want to create a list of squares of numbers from 0 to 9.
#
# Without list comprehension:
#
# ```python
# squares = []
# for x in range(10):
#     squares.append(x**2)
# print(squares)  # Output: [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# ```
#
# Using list comprehension:
#
# ```python
# squares = [x**2 for x in range(10)]
# print(squares)  # Output: [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# ```
#
# **Explanation**: The expression `x**2` computes the square of `x`, and we generate this for each `x` in `range(10)`.
#
# #### Example 2: Filtering with a Condition
# Let’s create a list of squared values but only for even numbers from 0 to 19.
#
# ```python
# even_squares = [x**2 for x in range(20) if x % 2 == 0]
# print(even_squares)  # Output: [0, 4, 16, 36, 64, 100, 144, 196]
# ```
#
# **Explanation**: The condition `if x % 2 == 0` only includes even numbers in the new list. So only squares of even numbers are calculated and added to `even_squares`.
#
# #### Example 3: Nested List Comprehensions
# You can use multiple list comprehensions nested inside each other. For example, to create a 3x3 matrix.
#
# ```python
# matrix = [[j for j in range(3)] for i in range(3)]
# print(matrix)  # Output: [[0, 1, 2], [0, 1, 2], [0, 1, 2]]
# ```
#
# **Explanation**: The outer comprehension runs three times (for `i`), and for each `i`, the inner comprehension creates a list of values `[0, 1, 2]`.
#
# #### Example 4: Transforming Data
# Let's convert a list of lowercased names to uppercase.
#
# Without list comprehension:
#
# ```python
# names = ["alice", "bob", "charlie"]
# uppercase_names = []
# for name in names:
#     uppercase_names.append(name.upper())
# print(uppercase_names)  # Output: ['ALICE', 'BOB', 'CHARLIE']
# ```
#
# Using list comprehension:
#
# ```python
# names = ["alice", "bob", "charlie"]
# uppercase_names = [name.upper() for name in names]
# print(uppercase_names)  # Output: ['ALICE', 'BOB', 'CHARLIE']
# ```
#
# **Explanation**: We apply the `upper()` method to each `name` in the `names` list.
#
# ### Conclusion
#
# List comprehensions make it easier and quicker to create new lists by applying transformations to existing iterables, often in fewer lines of code. They can improve readability when used appropriately, but it’s important to keep them simple to avoid confusion.
#
# If there’s a specific part you’d like to explore further or if you have examples you’d like me to clarify, please let me know!
